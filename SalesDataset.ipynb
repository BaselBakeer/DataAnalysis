# %% [markdown]
# 1 find Best selling product
# 2 find total sales
# 3 profit margins
# 4 data visualization

# %%
import pandas as pd
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
salesdf = pd.read_csv("C://Users//Basel Bakeer//Desktop//meskil internship//Dataset MeriSKILL//Sales Data.csv")

# %%
salesdf
# Out:
#         Unnamed: 0  Order ID                 Product  Quantity Ordered  \
# 0                0    295665      Macbook Pro Laptop                 1
# 1                1    295666      LG Washing Machine                 1
# 2                2    295667    USB-C Charging Cable                 1
# 3                3    295668        27in FHD Monitor                 1
# 4                4    295669    USB-C Charging Cable                 1
# ...            ...       ...                     ...               ...
# 185945       13617    222905  AAA Batteries (4-pack)                 1
# 185946       13618    222906        27in FHD Monitor                 1
# 185947       13619    222907    USB-C Charging Cable                 1
# 185948       13620    222908    USB-C Charging Cable                 1
# 185949       13621    222909  AAA Batteries (4-pack)                 1
#
#         Price Each           Order Date  \
# 0          1700.00  2019-12-30 00:01:00
# ...

# %%
salesdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185950 entries, 0 to 185949
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        185950 non-null  int64
#  1   Order ID          185950 non-null  int64
#  2   Product           185950 non-null  object
#  3   Quantity Ordered  185950 non-null  int64
#  4   Price Each        185950 non-null  float64
#  5   Order Date        185950 non-null  object
#  6   Purchase Address  185950 non-null  object
#  7   Month             185950 non-null  int64
#  8   Sales             185950 non-null  float64
#  9   City              185950 non-null  object
#  10  Hour              185950 non-null  int64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 15.6+ MB

# %%
salesdf['Sales'].sum()
# Out:
# 34492035.97

# %% [markdown]
# total sales = 34492035.97

# %%
salesdf['Product'].count()
# Out:
# 185950

# %%
product_group=salesdf.groupby('Product')
quantity_ordered=product_group.sum()['Quantity Ordered']
products=[Product for Product, df in product_group]

# %%
plt.bar(products,quantity_ordered)
plt.xticks(rotation='vertical', size=8)
plt.xlabel('product')
plt.ylabel('quantity')
plt.show()

# %% [markdown]
# most selling product is AAA Batteries (4-pack)

# %%
saless=salesdf.groupby('Sales')
product_ordered=product_group.sum()['Sales']

# %%
product_ordered.sort_values(ascending=False)
# Out:
# Product
# Macbook Pro Laptop            8037600.00
# iPhone                        4794300.00
# ThinkPad Laptop               4129958.70
# Google Phone                  3319200.00
# 27in 4K Gaming Monitor        2435097.56
# 34in Ultrawide Monitor        2355558.01
# Apple Airpods Headphones      2349150.00
# Flatscreen TV                 1445700.00
# Bose SoundSport Headphones    1345565.43
# 27in FHD Monitor              1132424.50
# Vareebadd Phone                827200.00
# 20in Monitor                   454148.71
# LG Washing Machine             399600.00
# LG Dryer                       387600.00
# Lightning Charging Cable       347094.15
# USB-C Charging Cable           286501.25
# Wired Headphones               246478.43
# AA Batteries (4-pack)          106118.40
# AAA Batteries (4-pack)          92740.83
# Name: Sales, dtype: float64

# %%
highrevenue=product_group.sum()['Sales']
prodcts=[Product for Product, df in product_group]

# %%
plt.bar(prodcts,highrevenue)
plt.xticks(rotation='vertical', size=8)
plt.xlabel('product')
plt.ylabel('Revenue')
plt.show()

# %%
monthlysales=salesdf.groupby('Month').sum()

# %%
monthlysales
# Out:
#        Unnamed: 0    Order ID  \
# Month
# 1        47433245  1421630798
# 2        72123197  1871052592
# 3       115333587  2564810956
# 4       167977608  3387347100
# 5       137829259  3345871523
# 6        92330356  2932976072
# 7       102752005  3284139576
# 8        71824951  2899373917
# 9        67863032  2948726831
# 10      206528743  5457110383
# 11      155210546  5047202573
# 12      313688708  7685904705
#
#                                                  Product  Quantity Ordered  \
# Month
# 1      Lightning Charging CableiPhoneLightning Chargi...             10903
# 2      iPhoneAA Batteries (4-pack)27in 4K Gaming Moni...             13449
# 3      AAA Batteries (4-pack)AAA Batteries (4-pack)Wi...             17005
# 4      USB-C Charging CableBose SoundSport Headphones...             20558
# 5      Apple Airpods Headphones27in FHD MonitoriPhone...             18667
# 6      27in FHD MonitorAAA Batteries (4-pack)Lightnin...             15253
# ...

# %%
monthss=range(1,13)
plt.bar(monthss,monthlysales['Sales'])
plt.xlabel('month')
plt.ylabel('sales')
# Out:
# Text(0, 0.5, 'sales')

# %%
citysales=salesdf.groupby('City').sum()

# %%
citysales
# Out:
#                 Unnamed: 0     Order ID  \
# City
#  Atlanta         122928154   3423838407
#  Austin           82709457   2280982185
#  Boston          165758780   4598265261
#  Dallas          124308328   3415643578
#  Los Angeles     247743297   6811084693
#  New York City   208439450   5736333884
#  Portland        104043698   2868861092
#  San Francisco   372569180  10304443952
#  Seattle         122394893   3406693974
#
#                                                           Product  \
# City
#  Atlanta        USB-C Charging CableWired HeadphonesAAA Batter...
#  Austin         Lightning Charging CableWired HeadphonesAA Bat...
#  Boston         AA Batteries (4-pack)Google PhoneUSB-C Chargin...
#  Dallas         USB-C Charging CableBose SoundSport Headphones...
#  Los Angeles    ThinkPad LaptopApple Airpods HeadphonesBose So...
#  New York City  Macbook Pro LaptopLG Washing MachineUSB-C Char...
#  Portland       USB-C Charging CableUSB-C Charging CableUSB-C ...
# ...

# %%
cities=[City for City, df in salesdf.groupby('City')]
plt.bar(cities,citysales['Sales'])
plt.xticks(cities,rotation='vertical',size=8)
plt.ylabel('sales')
plt.xlabel('city')
# Out:
# Text(0.5, 0, 'city')
