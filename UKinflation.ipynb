# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import tensorflow as TF

# %%
monthlyInflation=pd.read_csv("E://my ml models//Data analysis//archive (11)//Inflation by Month.csv")

# %%
yearlyInflation=pd.read_csv("E://my ml models//Data analysis//archive (11)//Inflation by Year.csv")

# %%
monthlyInflation
# Out:
#      Year Month  Inflation
# 0    1989   JAN        5.7
# 1    1989   FEB        5.8
# 2    1989   MAR        5.9
# 3    1989   APR        5.6
# 4    1989   MAY        5.9
# ..    ...   ...        ...
# 410  2023   MAR        8.9
# 411  2023   APR        7.8
# 412  2023   MAY        7.9
# 413  2023   JUN        7.3
# 414  2023   JUL        6.4
#
# [415 rows x 3 columns]

# %%
monthlyInflation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 415 entries, 0 to 414
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Year       415 non-null    int64
#  1   Month      415 non-null    object
#  2   Inflation  415 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 9.9+ KB

# %%
yearlyInflation
# Out:
#     Year  Inflation
# 0   1989        5.7
# 1   1990        8.0
# 2   1991        7.5
# 3   1992        4.6
# 4   1993        2.6
# 5   1994        2.2
# 6   1995        2.7
# 7   1996        2.9
# 8   1997        2.2
# 9   1998        1.8
# 10  1999        1.7
# 11  2000        1.2
# 12  2001        1.6
# 13  2002        1.5
# 14  2003        1.4
# 15  2004        1.4
# 16  2005        2.1
# 17  2006        2.5
# 18  2007        2.4
# 19  2008        3.5
# 20  2009        2.0
# 21  2010        2.5
# 22  2011        3.8
# 23  2012        2.6
# 24  2013        2.3
# 25  2014        1.5
# 26  2015        0.4
# 27  2016        1.0
# 28  2017        2.6
# 29  2018        2.3
# 30  2019        1.7
# 31  2020        1.0
# 32  2021        2.5
# 33  2022        7.9

# %%
yearlyInflation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Year       34 non-null     int64
#  1   Inflation  34 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 672.0 bytes

# %%
monthToNmber={
    "JAN": "-01-01",
    "FEB": '-02-01',
    "MAR": '-03-01',
    "APR": '-04-01',
    "MAY": '-05-01',
    "JUN": '-06-01',
    "JUL": '-07-01',
    "AUG": '-08-01',
    "SEP": '-09-01',
    "OCT": '-10-01',
    "NOV": '-11-01',
    "DEC": '-12-01'

    }
monthlyInflation['Month']=monthlyInflation['Month'].map(monthToNmber)

# %%
monthlyInflation
# Out:
#      Year   Month  Inflation
# 0    1989  -01-01        5.7
# 1    1989  -02-01        5.8
# 2    1989  -03-01        5.9
# 3    1989  -04-01        5.6
# 4    1989  -05-01        5.9
# ..    ...     ...        ...
# 410  2023  -03-01        8.9
# 411  2023  -04-01        7.8
# 412  2023  -05-01        7.9
# 413  2023  -06-01        7.3
# 414  2023  -07-01        6.4
#
# [415 rows x 3 columns]

# %%
monthlyInflation['Year'] = monthlyInflation['Year'].astype(str) +monthlyInflation['Month']

# %%
monthlyInflation
# Out:
#            Year   Month  Inflation
# 0    1989-01-01  -01-01        5.7
# 1    1989-02-01  -02-01        5.8
# 2    1989-03-01  -03-01        5.9
# 3    1989-04-01  -04-01        5.6
# 4    1989-05-01  -05-01        5.9
# ..          ...     ...        ...
# 410  2023-03-01  -03-01        8.9
# 411  2023-04-01  -04-01        7.8
# 412  2023-05-01  -05-01        7.9
# 413  2023-06-01  -06-01        7.3
# 414  2023-07-01  -07-01        6.4
#
# [415 rows x 3 columns]

# %%
monthlyInflation.drop('Month',axis=1,inplace=True)

# %%
monthlyInflation
# Out:
#            Year  Inflation
# 0    1989-01-01        5.7
# 1    1989-02-01        5.8
# 2    1989-03-01        5.9
# 3    1989-04-01        5.6
# 4    1989-05-01        5.9
# ..          ...        ...
# 410  2023-03-01        8.9
# 411  2023-04-01        7.8
# 412  2023-05-01        7.9
# 413  2023-06-01        7.3
# 414  2023-07-01        6.4
#
# [415 rows x 2 columns]

# %%
monthlyInflation['Year'] = pd.to_datetime(monthlyInflation['Year'], yearfirst=True)

# %%
monthlyInflation.rename(columns={'Year':'Date'},inplace=True)

# %%
monthlyInflation
# Out:
#           Date  Inflation
# 0   1989-01-01        5.7
# 1   1989-02-01        5.8
# 2   1989-03-01        5.9
# 3   1989-04-01        5.6
# 4   1989-05-01        5.9
# ..         ...        ...
# 410 2023-03-01        8.9
# 411 2023-04-01        7.8
# 412 2023-05-01        7.9
# 413 2023-06-01        7.3
# 414 2023-07-01        6.4
#
# [415 rows x 2 columns]

# %%
sns.lineplot(data=monthlyInflation,x='Date',y='Inflation')
plt.show()

# %% [markdown]
# sns.scatterplot(data=monthlyInflation, x="Date", y="Inflation")

# %%
monthlyInflation.boxplot()
# Out:
# <Axes: >

# %%
median of the inflation is 2.3 
maximum of the inflation is 9.6
minimum of the inflation is 0.2
