# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
diabetes=pd.read_csv("C://Users//Basel Bakeer//Desktop//meskil internship//Dataset MeriSKILL//Diabetes//diabetes.csv")

# %%
diabetes
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
plt.bar(diabetes['Age'],diabetes['Outcome'])
# Out:
# <BarContainer object of 768 artists>

# %%
import seaborn as sns

# %%
sns.lineplot(data=diabetes,x='Glucose',y='Outcome')
plt.show()

# %%
sns.lineplot(data=diabetes,x='SkinThickness',y='Outcome')
plt.show()

# %%
sns.lineplot(data=diabetes,x='Pregnancies',y='Outcome')
plt.show()

# %%
sns.lineplot(data=diabetes,x='DiabetesPedigreeFunction',y='Outcome')
plt.show()

# %%
corr = diabetes.corr()
print(corr)
sns.heatmap(corr, 
         xticklabels=corr.columns, 
         yticklabels=corr.columns)
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %% [markdown]
# as we see the correlation shows that all variables are co related to diabetes

# %%
x=diabetes.drop('Outcome',axis=1)
y=diabetes['Outcome']

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.35)

print("Training Data Shape : ", xtrain.shape, ytrain.shape)
print("Test Data Shape : ", xtest.shape, ytest.shape)
# Out:
# Training Data Shape :  (499, 8) (499,)
# Test Data Shape :  (269, 8) (269,)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier(max_depth=20,min_samples_split =20,min_samples_leaf =10)

# %%
rf.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier(max_depth=20, min_samples_leaf=10, min_samples_split=20)

# %%
rf.score(xtrain,ytrain)
# Out:
# 0.8356713426853707

# %%
rf.score(xtest,ytest)
# Out:
# 0.8215613382899628
